# %% [markdown]
# <a href="https://colab.research.google.com/github/ishaannandoskar-05/Deep-Learning/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [1], [1], [0]])

model = Sequential()
model.add(Dense(2, input_dim=2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer=SGD(learning_rate=0.1), metrics=['accuracy'])

model.fit(X, y, epochs=10000, verbose=0)

loss, accuracy = model.evaluate(X, y)
print(f"Loss: {loss}, Accuracy: {accuracy}")

predictions = model.predict(X)
print("Predictions:")
for i in range(len(X)):
    print(f"Input: {X[i]}, Predicted Output: {predictions[i]}, Actual Output: {y[i]}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 1.0000 - loss: 0.0169
# Loss: 0.016936147585511208, Accuracy: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Predictions:
# Input: [0 0], Predicted Output: [0.01300771], Actual Output: [0]
# Input: [0 1], Predicted Output: [0.9848712], Actual Output: [1]
# Input: [1 0], Predicted Output: [0.9849133], Actual Output: [1]
# Input: [1 1], Predicted Output: [0.02391491], Actual Output: [0]
